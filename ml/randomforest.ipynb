# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from cryptocmd import CmcScraper

# initialise scraper with coin name as well
scraper = CmcScraper(coin_code="XRP", coin_name="XRP")

# get raw data as list of list
headers, data = scraper.get_data()

# get data in a json format
xrp_json_data = scraper.get_data("json")

# export the data as csv file, you can also pass optional name parameter
scraper.export("csv", name="xrp_all_time")

# Pandas dataFrame for the same data
xrp = scraper.get_dataframe()

# %%
from cryptocmd import CmcScraper

# initialise scraper with coin name as well
scraper = CmcScraper(coin_code="ETH", coin_name="Ethereum")

# get raw data as list of list
headers, data = scraper.get_data()

# get data in a json format
ethereum_json_data = scraper.get_data("json")

# export the data as csv file, you can also pass optional name parameter
scraper.export("csv", name="eth_all_time")

# Pandas dataFrame for the same data
Ethereum = scraper.get_dataframe()

# %%
from cryptocmd import CmcScraper

# initialise scraper with coin name as well
scraper = CmcScraper(coin_code="DOGE", coin_name="Dogecoin")

# get raw data as list of list
headers, data = scraper.get_data()

# get data in a json format
dogecoin_json_data = scraper.get_data("json")

# export the data as csv file, you can also pass optional name parameter
scraper.export("csv", name="doge_all_time")

# Pandas dataFrame for the same data
doge_coin = scraper.get_dataframe()

# %%
from cryptocmd import CmcScraper

# initialise scraper with coin name as well
scraper = CmcScraper(coin_code="AAVE", coin_name="Aave")

# get raw data as list of list
headers, data = scraper.get_data()

# get data in a json format
aave_json_data = scraper.get_data("json")

# export the data as csv file, you can also pass optional name parameter
scraper.export("csv", name="aave_all_time")

# Pandas dataFrame for the same data
aave = scraper.get_dataframe()

# %%
from cryptocmd import CmcScraper

# initialise scraper with coin name as well
scraper = CmcScraper(coin_code="BTC", coin_name="Bitcoin")

# get raw data as list of list
headers, data = scraper.get_data()

# get data in a json format
bitcoin_json_data = scraper.get_data("json")

# export the data as csv file, you can also pass optional name parameter
scraper.export("csv", name="btc_all_time")

# Pandas dataFrame for the same data
bitcoin = scraper.get_dataframe()

# %%
df_btc = pd.read_csv("btc_all_time.csv")
df_eth = pd.read_csv("eth_all_time.csv")
df_aave = pd.read_csv("aave_all_time.csv")
df_xrp = pd.read_csv("xrp_all_time.csv")
df_doge = pd.read_csv("doge_all_time.csv")

# %%
df_btc.head(5)
# Out:
#          Date          Open          High           Low         Close  \
# 0  05-05-2024  63892.454987  64610.890215  62955.306476  64031.132809
# 1  04-05-2024  62891.030548  64494.958426  62599.353147  63891.472918
# 2  03-05-2024  59122.300852  63320.503389  58848.312059  62889.836744
# 3  02-05-2024  58253.704700  59602.298028  56937.204168  59123.432247
# 4  01-05-2024  60609.497946  60780.499677  56555.294055  58254.009853
#
#          Volume    Market Cap                 Time Open  \
# 0  1.829616e+10  1.261204e+12  2024-05-05T00:00:00.000Z
# 1  2.062048e+10  1.258305e+12  2024-05-04T00:00:00.000Z
# 2  3.317202e+10  1.238554e+12  2024-05-03T00:00:00.000Z
# 3  3.271181e+10  1.164331e+12  2024-05-02T00:00:00.000Z
# 4  4.843978e+10  1.147184e+12  2024-05-01T00:00:00.000Z
#
#                   Time High                  Time Low  \
# 0  2024-05-05T15:58:00.000Z  2024-05-05T01:37:00.000Z
# 1  2024-05-04T11:02:00.000Z  2024-05-04T02:37:00.000Z
# ...

# %%
df_btc = df_btc.drop(["Date", "Time High", "Time Low",
             "Time Close", "Time Open"], axis=1)

df_eth = df_eth.drop(["Date", "Time High", "Time Low",
                "Time Close", "Time Open"], axis=1)

df_aave = df_aave.drop(["Date", "Time High", "Time Low",
                "Time Close", "Time Open"], axis=1)

df_xrp = df_xrp.drop(["Date", "Time High", "Time Low",
                "Time Close", "Time Open"], axis=1)

df_doge = df_doge.drop(["Date", "Time High", "Time Low",
                "Time Close", "Time Open"], axis=1)

# %%
df_btc.head()
# Out:
#            Open          High           Low         Close        Volume  \
# 0  63892.454987  64610.890215  62955.306476  64031.132809  1.829616e+10
# 1  62891.030548  64494.958426  62599.353147  63891.472918  2.062048e+10
# 2  59122.300852  63320.503389  58848.312059  62889.836744  3.317202e+10
# 3  58253.704700  59602.298028  56937.204168  59123.432247  3.271181e+10
# 4  60609.497946  60780.499677  56555.294055  58254.009853  4.843978e+10
#
#      Market Cap
# 0  1.261204e+12
# 1  1.258305e+12
# 2  1.238554e+12
# 3  1.164331e+12
# 4  1.147184e+12

# %%
def log_transform(df):
    return df.apply(lambda x: np.log(x + 1))

# %%
df_btc= log_transform(df_btc)
df_eth= log_transform(df_eth)
df_aave=log_transform(df_aave)
df_xrp= log_transform(df_xrp)
df_doge= log_transform(df_doge)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Function to plot histograms for each column
def plot_histograms(dataframe):
    # Number of rows and columns for subplot grid
    n_cols = 3
    n_rows = (len(dataframe.columns) + n_cols - 1) // n_cols
    
    fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(14, 6))
    axes = axes.flatten()  # Flatten the axes array for easy iteration

    for i, column in enumerate(dataframe.columns):
        dataframe[column].hist(ax=axes[i], bins=10, alpha=0.75, color='blue')
        axes[i].set_title(f'Histogram of {column}')
        axes[i].set_xlabel(column)
        axes[i].set_ylabel('Frequency')

    # Hide unused axes if any
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')

    plt.tight_layout()
    plt.show()

plot_histograms(df_btc)
plot_histograms(df_eth)
plot_histograms(df_aave)
plot_histograms(df_xrp)
plot_histograms(df_doge)

# %%
# Convert the scaled data back to a DataFrame
scaled_btc = pd.DataFrame(df_btc, columns=df_btc.columns)
scaled_eth = pd.DataFrame(df_eth, columns=df_eth.columns)
scaled_aave = pd.DataFrame(df_aave, columns=df_aave.columns)
scaled_xrp = pd.DataFrame(df_xrp, columns=df_xrp.columns)
scaled_doge = pd.DataFrame(df_doge, columns=df_doge.columns)

# %%
scaled_btc.head()
# Out:
#        Open      High       Low     Close    Volume  Market Cap
# 0  2.490306  2.491233  2.489081  2.490486  3.203963    3.362564
# 1  2.488996  2.491084  2.488610  2.490305  3.208807    3.362484
# 2  2.483854  2.489561  2.483467  2.488995  3.227834    3.361935
# 3  2.482619  2.484529  2.480708  2.483856  3.227280    3.359791
# 4  2.485925  2.486159  2.480145  2.482619  3.242732    3.359275

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

def perform_k_fold_cv(dataframe, n_splits=5, random_state=42):
    X = dataframe.drop('High', axis=1)
    y = dataframe['High']

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    rmse_scores_train = []
    rmse_scores_test = []
    r2_scores_train = []
    r2_scores_test = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        model = RandomForestRegressor(n_estimators=500, random_state=random_state)
        model.fit(X_train, y_train)

        # Predictions for train and test
        y_train_pred = model.predict(X_train)
        y_test_pred = model.predict(X_test)

        # RMSE for train and test
        rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
        rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
        rmse_scores_train.append(rmse_train)
        rmse_scores_test.append(rmse_test)

        # R2 for train and test
        r2_train = r2_score(y_train, y_train_pred)
        r2_test = r2_score(y_test, y_test_pred)
        r2_scores_train.append(r2_train)
        r2_scores_test.append(r2_test)

    # Averages
    avg_rmse_train = np.mean(rmse_scores_train)
    avg_rmse_test = np.mean(rmse_scores_test)
    avg_r2_train = np.mean(r2_scores_train)
    avg_r2_test = np.mean(r2_scores_test)

    return avg_rmse_train, avg_rmse_test, avg_r2_train, avg_r2_test


cryptos = ['BTC', 'ETH', 'AAVE', 'XRP', 'DOGE']
datasets = [scaled_btc, scaled_eth, scaled_aave, scaled_xrp, scaled_doge]

results = {}
for crypto, dataset in zip(cryptos, datasets):
    results[crypto] = perform_k_fold_cv(dataset)

df_results = pd.DataFrame(results, index=['avg_rmse_train', 'avg_rmse_test', 'avg_r2_train', 'avg_r2_test']).T

# Plotting RMSE and R2 scores
plt.figure(figsize=(14, 7))

# RMSE plot
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
plt.plot(df_results.index, df_results['avg_rmse_train'], label='Train RMSE', marker='o')
plt.plot(df_results.index, df_results['avg_rmse_test'], label='Test RMSE', marker='o')
plt.title('Average RMSE Scores by Cryptocurrency')
plt.ylabel('RMSE')
plt.xlabel('Cryptocurrency')
plt.legend()

# R2 plot
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
plt.plot(df_results.index, df_results['avg_r2_train'], label='Train R2', marker='o')
plt.plot(df_results.index, df_results['avg_r2_test'], label='Test R2', marker='o')
plt.title('Average R2 Scores by Cryptocurrency')
plt.ylabel('R2 Score')
plt.xlabel('Cryptocurrency')
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import KFold
import numpy as np

def perform_k_fold_cv(dataframe, n_splits=5, random_state=42):
    X = dataframe.drop('High', axis=1)
    y = dataframe['High']

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    rmse_scores_train = []
    rmse_scores_test = []
    r2_scores_train = []
    r2_scores_test = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Define the parameter grid to search
        param_grid = {
            'n_estimators': [800, 1200],
            'max_depth': [25, 30],
            'min_samples_split': [10, 15],
            'min_samples_leaf': [5, 10]
        }

        rf = RandomForestRegressor(random_state=random_state)
        rf_random = RandomizedSearchCV(estimator=rf, param_distributions=param_grid, n_iter=30,
                                       cv=3, verbose=2, random_state=random_state, n_jobs=-1)

        rf_random.fit(X_train, y_train)

        best_random = rf_random.best_estimator_

        # Predictions for train and test
        y_train_pred = best_random.predict(X_train)
        y_test_pred = best_random.predict(X_test)

        # RMSE for train and test
        rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
        rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
        rmse_scores_train.append(rmse_train)
        rmse_scores_test.append(rmse_test)

        # R2 for train and test
        r2_train = r2_score(y_train, y_train_pred)
        r2_test = r2_score(y_test, y_test_pred)
        r2_scores_train.append(r2_train)
        r2_scores_test.append(r2_test)

    # Averages
    avg_rmse_train = np.mean(rmse_scores_train)
    avg_rmse_test = np.mean(rmse_scores_test)
    avg_r2_train = np.mean(r2_scores_train)
    avg_r2_test = np.mean(r2_scores_test)

    return avg_rmse_train, avg_rmse_test, avg_r2_train, avg_r2_test
cryptos = ['BTC', 'ETH', 'AAVE', 'XRP', 'DOGE']
datasets = [scaled_btc, scaled_eth, scaled_aave, scaled_xrp, scaled_doge]

results = {}
for crypto, dataset in zip(cryptos, datasets):
    results[crypto] = perform_k_fold_cv(dataset)

df_results = pd.DataFrame(results, index=['avg_rmse_train', 'avg_rmse_test', 'avg_r2_train', 'avg_r2_test']).T

# Plotting RMSE and R2 scores
plt.figure(figsize=(14, 7))

# RMSE plot
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
plt.plot(df_results.index, df_results['avg_rmse_train'], label='Train RMSE', marker='o')
plt.plot(df_results.index, df_results['avg_rmse_test'], label='Test RMSE', marker='o')
plt.title('Average RMSE Scores by Cryptocurrency')
plt.ylabel('RMSE')
plt.xlabel('Cryptocurrency')
plt.legend()

# R2 plot
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
plt.plot(df_results.index, df_results['avg_r2_train'], label='Train R2', marker='o')
plt.plot(df_results.index, df_results['avg_r2_test'], label='Test R2', marker='o')
plt.title('Average R2 Scores by Cryptocurrency')
plt.ylabel('R2 Score')
plt.xlabel('Cryptocurrency')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /Users/sowmyaneela/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 16 is smaller than n_iter=30. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# /Users/sowmyaneela/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 16 is smaller than n_iter=30. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# /Users/sowmyaneela/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 16 is smaller than n_iter=30. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# ...
